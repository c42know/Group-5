# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
from pprint import pprint

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

#http://history.openweathermap.org/data/2.5/history/city?id={id}&type=hour&start={start}&end={end}

# %%
# Get data for each city in cities.csv
#cities = ['washington dc', 'san francisco' , 'new york city', 'chicago', 'atlanta', 'las vegas']
cities = ['san francisco' , 'new york', 'chicago', 'atlanta', 'las vegas']

#cities = ["Paris", "London", "Oslo", "Beijing"]

# set up lists to hold reponse info
lat = []
temp = []
wind = []
desc = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    pprint(response)
    pprint(response['coord']['lat'])
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])
    wind.append(response['wind']['speed'])
    #desc.append(response['weather']['description'])

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 37.78, 'lon': -122.42},
#  'dt': 1523486100,
#  'id': 5391959,
#  'main': {'humidity': 76,
#           'pressure': 1018,
#           'temp': 59,
#           'temp_max': 60.8,
#           'temp_min': 57.2},
#  'name': 'San Francisco',
#  'sys': {'country': 'US',
#          'id': 392,
#          'message': 0.0049,
#          'sunrise': 1523453919,
#          'sunset': 1523500964,
#          'type': 1},
#  'visibility': 11265,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 10.29}}
# 37.78
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 40.73, 'lon': -73.99},
#  'dt': 1523484900,
#  'id': 5128581,
#  'main': {'humidity': 32,
#           'pressure': 1018,
#           'temp': 48.2,
#           'temp_max': 51.8,
#           'temp_min': 44.6},
#  'name': 'New York',
#  'sys': {'country': 'US',
#          'id': 1969,
#          'message': 0.0254,
#          'sunrise': 1523442114,
#          'sunset': 1523489533,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'gust': 7.7, 'speed': 3.36}}
# 40.73
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.88, 'lon': -87.62},
#  'dt': 1523482500,
#  'id': 4887398,
#  'main': {'humidity': 40,
#           'pressure': 1012,
#           'temp': 64.33,
#           'temp_max': 68,
#           'temp_min': 59},
#  'name': 'Chicago',
#  'sys': {'country': 'US',
#          'id': 966,
#          'message': 0.0039,
#          'sunrise': 1523445303,
#          'sunset': 1523492887,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'haze', 'icon': '50d', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 240, 'gust': 7.7, 'speed': 11.41}}
# 41.88
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 33.75, 'lon': -84.39},
#  'dt': 1523486100,
#  'id': 4180439,
#  'main': {'humidity': 32,
#           'pressure': 1022,
#           'temp': 68.36,
#           'temp_max': 69.8,
#           'temp_min': 66.2},
#  'name': 'Atlanta',
#  'sys': {'country': 'US',
#          'id': 749,
#          'message': 0.0116,
#          'sunrise': 1523445041,
#          'sunset': 1523491586,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 336.501, 'speed': 4.88}}
# 33.75
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 36.17, 'lon': -115.15},
#  'dt': 1523484900,
#  'id': 5506956,
#  'main': {'humidity': 5,
#           'pressure': 1007,
#           'temp': 90.48,
#           'temp_max': 93.2,
#           'temp_min': 89.6},
#  'name': 'Las Vegas',
#  'sys': {'country': 'US',
#          'id': 2049,
#          'message': 0.0046,
#          'sunrise': 1523452276,
#          'sunset': 1523499116,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'gust': 15.9, 'speed': 25.28}}
# 36.17
# The latitude information received is: [37.78, 40.73, 41.88, 33.75, 36.17]
# The temperature information received is: [59, 48.2, 64.33, 68.36, 90.48]

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
    "lat": lat,
    "Temperature": temp,
    "Wind": wind
    #"Climate Type": desc
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#    Temperature   Wind           city    lat
# 0        59.00  10.29  san francisco  37.78
# 1        48.20   3.36       new york  40.73
# 2        64.33  11.41        chicago  41.88
# 3        68.36   4.88        atlanta  33.75
# 4        90.48  25.28      las vegas  36.17

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda2/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-32ea4c10a8b6> in <module>()
#       1 # Build a scatter plot for each data type
# ----> 2 plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("Temperature in World Cities")
#
# /anaconda2/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda2/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda2/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda2/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda2/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temp'

# %%
#cities = ['washington dc', 'san francisco' , 'new york city', 'chicago', 'atlanta', 'las vegas']
cities = ['washington dc.','san francisco' , 'new york', 'chicago', 'atlanta', 'las vegas']

#cities = ["Paris", "London", "Oslo", "Beijing"]

# set up lists to hold reponse info
lat = []
temp = []
wind = []
desc = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    #pprint(response)
    #pprint(response['weather'][0]['main'])
    #pprint(response['coord']['lat'])
    temp.append(response['main']['temp'])
    wind.append(response['wind']['speed'])
    desc.append(response['weather'][0]['main'])

print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: []
# The temperature information received is: [52.59, 59, 46.85, 56.34, 64.2, 88.38]

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
#     "lat": lat,
     "Temperature": temp,
     "Wind": wind,
    "Climate Type": desc
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head(10)
# Out:
#   Climate Type  Temperature   Wind            city
# 0       Clouds        52.59   8.05  washington dc.
# 1       Clouds        59.00  20.80   san francisco
# 2       Clouds        46.85   5.55        new york
# 3         Haze        56.34   6.93         chicago
# 4        Clear        64.20   4.88         atlanta
# 5       Clouds        88.38  17.22       las vegas

# %%
desc
# Out:
# ['Clouds', 'Clouds', 'Clouds', 'Haze', 'Clear', 'Clouds']
